Table52 = pd.read_csv('C:\Users\Ty Dickinson\Documents\Hollings Code Output Excels\Max Precip\Wimberley 1 NW.csv')

Winter1DayMax = []
Winter1DayStation = []

Spring1DayMax = []
Spring1DayStation = []

Summer1DayMax = []
Summer1DayStation = []

Fall1DayMax = []
Fall1DayStation = []

Winter2DayMax = []
Winter2DayStation = []

Spring2DayMax = []
Spring2DayStation = []

Summer2DayMax = []
Summer2DayStation = []

Fall2DayMax = []
Fall2DayStation = []



for i in range(0, 36):
    List = [Table1['Winter 1 Day Precip'][i], Table2['Winter 1 Day Precip'][i],  Table3['Winter 1 Day Precip'][i],
              Table4['Winter 1 Day Precip'][i], Table5['Winter 1 Day Precip'][i],  Table6['Winter 1 Day Precip'][i],
              Table7['Winter 1 Day Precip'][i], Table8['Winter 1 Day Precip'][i], Table9['Winter 1 Day Precip'][i],
              Table10['Winter 1 Day Precip'][i], Table11['Winter 1 Day Precip'][i], Table12['Winter 1 Day Precip'][i],
              Table13['Winter 1 Day Precip'][i], Table14['Winter 1 Day Precip'][i], Table15['Winter 1 Day Precip'][i],
              Table16['Winter 1 Day Precip'][i], Table17['Winter 1 Day Precip'][i], Table18['Winter 1 Day Precip'][i],
              Table19['Winter 1 Day Precip'][i], Table20['Winter 1 Day Precip'][i], Table21['Winter 1 Day Precip'][i],
              Table22['Winter 1 Day Precip'][i], Table23['Winter 1 Day Precip'][i], Table24['Winter 1 Day Precip'][i],
              Table25['Winter 1 Day Precip'][i], Table26['Winter 1 Day Precip'][i], Table27['Winter 1 Day Precip'][i],
              Table28['Winter 1 Day Precip'][i], Table29['Winter 1 Day Precip'][i], Table30['Winter 1 Day Precip'][i],
              Table31['Winter 1 Day Precip'][i], Table32['Winter 1 Day Precip'][i], Table33['Winter 1 Day Precip'][i],
              Table34['Winter 1 Day Precip'][i], Table35['Winter 1 Day Precip'][i], Table36['Winter 1 Day Precip'][i],
              Table37['Winter 1 Day Precip'][i], Table38['Winter 1 Day Precip'][i], Table39['Winter 1 Day Precip'][i],
              Table40['Winter 1 Day Precip'][i], Table41['Winter 1 Day Precip'][i], Table42['Winter 1 Day Precip'][i],
              Table43['Winter 1 Day Precip'][i], Table44['Winter 1 Day Precip'][i], Table45['Winter 1 Day Precip'][i],
              Table46['Winter 1 Day Precip'][i], Table47['Winter 1 Day Precip'][i], Table48['Winter 1 Day Precip'][i],
              Table49['Winter 1 Day Precip'][i], Table50['Winter 1 Day Precip'][i], Table51['Winter 1 Day Precip'][i],
              Table52['Winter 1 Day Precip'][i]]
    Winter1DayMax.insert(i, max(List))
    Winter1DayStation.insert(i, (List.index(max(List))+1)) #lists the number of the station with the max based on above
    i = i + 1

for i in range(0, 36):
    List = [Table1['Spring 1 Day Precip'][i], Table2['Spring 1 Day Precip'][i],  Table3['Spring 1 Day Precip'][i],
              Table4['Spring 1 Day Precip'][i], Table5['Spring 1 Day Precip'][i],  Table6['Spring 1 Day Precip'][i],
              Table7['Spring 1 Day Precip'][i], Table8['Spring 1 Day Precip'][i], Table9['Spring 1 Day Precip'][i],
              Table10['Spring 1 Day Precip'][i], Table11['Spring 1 Day Precip'][i], Table12['Spring 1 Day Precip'][i],
              Table13['Spring 1 Day Precip'][i], Table14['Spring 1 Day Precip'][i], Table15['Spring 1 Day Precip'][i],
              Table16['Spring 1 Day Precip'][i], Table17['Spring 1 Day Precip'][i], Table18['Spring 1 Day Precip'][i],
              Table19['Spring 1 Day Precip'][i], Table20['Spring 1 Day Precip'][i], Table21['Spring 1 Day Precip'][i],
              Table22['Spring 1 Day Precip'][i], Table23['Spring 1 Day Precip'][i], Table24['Spring 1 Day Precip'][i],
              Table25['Spring 1 Day Precip'][i], Table26['Spring 1 Day Precip'][i], Table27['Spring 1 Day Precip'][i],
              Table28['Spring 1 Day Precip'][i], Table29['Spring 1 Day Precip'][i], Table30['Spring 1 Day Precip'][i],
              Table31['Spring 1 Day Precip'][i], Table32['Spring 1 Day Precip'][i], Table33['Spring 1 Day Precip'][i],
              Table34['Spring 1 Day Precip'][i], Table35['Spring 1 Day Precip'][i], Table36['Spring 1 Day Precip'][i],
              Table37['Spring 1 Day Precip'][i], Table38['Spring 1 Day Precip'][i], Table39['Spring 1 Day Precip'][i],
              Table40['Spring 1 Day Precip'][i], Table41['Spring 1 Day Precip'][i], Table42['Spring 1 Day Precip'][i],
              Table43['Spring 1 Day Precip'][i], Table44['Spring 1 Day Precip'][i], Table45['Spring 1 Day Precip'][i],
              Table46['Spring 1 Day Precip'][i], Table47['Spring 1 Day Precip'][i], Table48['Spring 1 Day Precip'][i],
              Table49['Spring 1 Day Precip'][i], Table50['Spring 1 Day Precip'][i], Table51['Spring 1 Day Precip'][i],
              Table52['Spring 1 Day Precip'][i]]
    Spring1DayMax.insert(i, max(List))
    Spring1DayStation.insert(i, (List.index(max(List))+1)) #lists the number of the station with the max based on above
    i = i + 1  
    
for i in range(0, 36):
    List = [Table1['Summer 1 Day Precip'][i], Table2['Summer 1 Day Precip'][i],  Table3['Summer 1 Day Precip'][i],
              Table4['Summer 1 Day Precip'][i], Table5['Summer 1 Day Precip'][i],  Table6['Summer 1 Day Precip'][i],
              Table7['Summer 1 Day Precip'][i], Table8['Summer 1 Day Precip'][i], Table9['Summer 1 Day Precip'][i],
              Table10['Summer 1 Day Precip'][i], Table11['Summer 1 Day Precip'][i], Table12['Summer 1 Day Precip'][i],
              Table13['Summer 1 Day Precip'][i], Table14['Summer 1 Day Precip'][i], Table15['Summer 1 Day Precip'][i],
              Table16['Summer 1 Day Precip'][i], Table17['Summer 1 Day Precip'][i], Table18['Summer 1 Day Precip'][i],
              Table19['Summer 1 Day Precip'][i], Table20['Summer 1 Day Precip'][i], Table21['Summer 1 Day Precip'][i],
              Table22['Summer 1 Day Precip'][i], Table23['Summer 1 Day Precip'][i], Table24['Summer 1 Day Precip'][i],
              Table25['Summer 1 Day Precip'][i], Table26['Summer 1 Day Precip'][i], Table27['Summer 1 Day Precip'][i],
              Table28['Summer 1 Day Precip'][i], Table29['Summer 1 Day Precip'][i], Table30['Summer 1 Day Precip'][i],
              Table31['Summer 1 Day Precip'][i], Table32['Summer 1 Day Precip'][i], Table33['Summer 1 Day Precip'][i],
              Table34['Summer 1 Day Precip'][i], Table35['Summer 1 Day Precip'][i], Table36['Summer 1 Day Precip'][i],
              Table37['Summer 1 Day Precip'][i], Table38['Summer 1 Day Precip'][i], Table39['Summer 1 Day Precip'][i],
              Table40['Summer 1 Day Precip'][i], Table41['Summer 1 Day Precip'][i], Table42['Summer 1 Day Precip'][i],
              Table43['Summer 1 Day Precip'][i], Table44['Summer 1 Day Precip'][i], Table45['Summer 1 Day Precip'][i],
              Table46['Summer 1 Day Precip'][i], Table47['Summer 1 Day Precip'][i], Table48['Summer 1 Day Precip'][i],
              Table49['Summer 1 Day Precip'][i], Table50['Summer 1 Day Precip'][i], Table51['Summer 1 Day Precip'][i],
              Table52['Summer 1 Day Precip'][i]]
    Summer1DayMax.insert(i, max(List))
    Summer1DayStation.insert(i, (List.index(max(List))+1)) #lists the number of the station with the max based on above
    i = i + 1
    
for i in range(0, 36):
    List = [Table1['Fall 1 Day Precip'][i], Table2['Fall 1 Day Precip'][i],  Table3['Fall 1 Day Precip'][i],
              Table4['Fall 1 Day Precip'][i], Table5['Fall 1 Day Precip'][i],  Table6['Fall 1 Day Precip'][i],
              Table7['Fall 1 Day Precip'][i], Table8['Fall 1 Day Precip'][i], Table9['Fall 1 Day Precip'][i],
              Table10['Fall 1 Day Precip'][i], Table11['Fall 1 Day Precip'][i], Table12['Fall 1 Day Precip'][i],
              Table13['Fall 1 Day Precip'][i], Table14['Fall 1 Day Precip'][i], Table15['Fall 1 Day Precip'][i],
              Table16['Fall 1 Day Precip'][i], Table17['Fall 1 Day Precip'][i], Table18['Fall 1 Day Precip'][i],
              Table19['Fall 1 Day Precip'][i], Table20['Fall 1 Day Precip'][i], Table21['Fall 1 Day Precip'][i],
              Table22['Fall 1 Day Precip'][i], Table23['Fall 1 Day Precip'][i], Table24['Fall 1 Day Precip'][i],
              Table25['Fall 1 Day Precip'][i], Table26['Fall 1 Day Precip'][i], Table27['Fall 1 Day Precip'][i],
              Table28['Fall 1 Day Precip'][i], Table29['Fall 1 Day Precip'][i], Table30['Fall 1 Day Precip'][i],
              Table31['Fall 1 Day Precip'][i], Table32['Fall 1 Day Precip'][i], Table33['Fall 1 Day Precip'][i],
              Table34['Fall 1 Day Precip'][i], Table35['Fall 1 Day Precip'][i], Table36['Fall 1 Day Precip'][i],
              Table37['Fall 1 Day Precip'][i], Table38['Fall 1 Day Precip'][i], Table39['Fall 1 Day Precip'][i],
              Table40['Fall 1 Day Precip'][i], Table41['Fall 1 Day Precip'][i], Table42['Fall 1 Day Precip'][i],
              Table43['Fall 1 Day Precip'][i], Table44['Fall 1 Day Precip'][i], Table45['Fall 1 Day Precip'][i],
              Table46['Fall 1 Day Precip'][i], Table47['Fall 1 Day Precip'][i], Table48['Fall 1 Day Precip'][i],
              Table49['Fall 1 Day Precip'][i], Table50['Fall 1 Day Precip'][i], Table51['Fall 1 Day Precip'][i],
              Table52['Fall 1 Day Precip'][i]]
    Fall1DayMax.insert(i, max(List))
    Fall1DayStation.insert(i, (List.index(max(List))+1)) #lists the number of the station with the max based on above
    i = i + 1

    
    
for i in range(0, 36):
    List = [Table1['Winter 2 Day Precip'][i], Table2['Winter 2 Day Precip'][i],  Table3['Winter 2 Day Precip'][i],
              Table4['Winter 2 Day Precip'][i], Table5['Winter 2 Day Precip'][i],  Table6['Winter 2 Day Precip'][i],
              Table7['Winter 2 Day Precip'][i], Table8['Winter 2 Day Precip'][i], Table9['Winter 2 Day Precip'][i],
              Table10['Winter 2 Day Precip'][i], Table11['Winter 2 Day Precip'][i], Table12['Winter 2 Day Precip'][i],
              Table13['Winter 2 Day Precip'][i], Table14['Winter 2 Day Precip'][i], Table15['Winter 2 Day Precip'][i],
              Table16['Winter 2 Day Precip'][i], Table17['Winter 2 Day Precip'][i], Table18['Winter 2 Day Precip'][i],
              Table19['Winter 2 Day Precip'][i], Table20['Winter 2 Day Precip'][i], Table21['Winter 2 Day Precip'][i],
              Table22['Winter 2 Day Precip'][i], Table23['Winter 2 Day Precip'][i], Table24['Winter 2 Day Precip'][i],
              Table25['Winter 2 Day Precip'][i], Table26['Winter 2 Day Precip'][i], Table27['Winter 2 Day Precip'][i],
              Table28['Winter 2 Day Precip'][i], Table29['Winter 2 Day Precip'][i], Table30['Winter 2 Day Precip'][i],
              Table31['Winter 2 Day Precip'][i], Table32['Winter 2 Day Precip'][i], Table33['Winter 2 Day Precip'][i],
              Table34['Winter 2 Day Precip'][i], Table35['Winter 2 Day Precip'][i], Table36['Winter 2 Day Precip'][i],
              Table37['Winter 2 Day Precip'][i], Table38['Winter 2 Day Precip'][i], Table39['Winter 2 Day Precip'][i],
              Table40['Winter 2 Day Precip'][i], Table41['Winter 2 Day Precip'][i], Table42['Winter 2 Day Precip'][i],
              Table43['Winter 2 Day Precip'][i], Table44['Winter 2 Day Precip'][i], Table45['Winter 2 Day Precip'][i],
              Table46['Winter 2 Day Precip'][i], Table47['Winter 2 Day Precip'][i], Table48['Winter 2 Day Precip'][i],
              Table49['Winter 2 Day Precip'][i], Table50['Winter 2 Day Precip'][i], Table51['Winter 2 Day Precip'][i],
              Table52['Winter 2 Day Precip'][i]]
    Winter2DayMax.insert(i, max(List))
    Winter2DayStation.insert(i, (List.index(max(List))+1)) #lists the number of the station with the max based on above
    i = i + 1

for i in range(0, 36):
    List = [Table1['Spring 2 Day Precip'][i], Table2['Spring 2 Day Precip'][i],  Table3['Spring 2 Day Precip'][i],
              Table4['Spring 2 Day Precip'][i], Table5['Spring 2 Day Precip'][i],  Table6['Spring 2 Day Precip'][i],
              Table7['Spring 2 Day Precip'][i], Table8['Spring 2 Day Precip'][i], Table9['Spring 2 Day Precip'][i],
              Table10['Spring 2 Day Precip'][i], Table11['Spring 2 Day Precip'][i], Table12['Spring 2 Day Precip'][i],
              Table13['Spring 2 Day Precip'][i], Table14['Spring 2 Day Precip'][i], Table15['Spring 2 Day Precip'][i],
              Table16['Spring 2 Day Precip'][i], Table17['Spring 2 Day Precip'][i], Table18['Spring 2 Day Precip'][i],
              Table19['Spring 2 Day Precip'][i], Table20['Spring 2 Day Precip'][i], Table21['Spring 2 Day Precip'][i],
              Table22['Spring 2 Day Precip'][i], Table23['Spring 2 Day Precip'][i], Table24['Spring 2 Day Precip'][i],
              Table25['Spring 2 Day Precip'][i], Table26['Spring 2 Day Precip'][i], Table27['Spring 2 Day Precip'][i],
              Table28['Spring 2 Day Precip'][i], Table29['Spring 2 Day Precip'][i], Table30['Spring 2 Day Precip'][i],
              Table31['Spring 2 Day Precip'][i], Table32['Spring 2 Day Precip'][i], Table33['Spring 2 Day Precip'][i],
              Table34['Spring 2 Day Precip'][i], Table35['Spring 2 Day Precip'][i], Table36['Spring 2 Day Precip'][i],
              Table37['Spring 2 Day Precip'][i], Table38['Spring 2 Day Precip'][i], Table39['Spring 2 Day Precip'][i],
              Table40['Spring 2 Day Precip'][i], Table41['Spring 2 Day Precip'][i], Table42['Spring 2 Day Precip'][i],
              Table43['Spring 2 Day Precip'][i], Table44['Spring 2 Day Precip'][i], Table45['Spring 2 Day Precip'][i],
              Table46['Spring 2 Day Precip'][i], Table47['Spring 2 Day Precip'][i], Table48['Spring 2 Day Precip'][i],
              Table49['Spring 2 Day Precip'][i], Table50['Spring 2 Day Precip'][i], Table51['Spring 2 Day Precip'][i],
              Table52['Spring 2 Day Precip'][i]]
    Spring2DayMax.insert(i, max(List))
    Spring2DayStation.insert(i, (List.index(max(List))+1)) #lists the number of the station with the max based on above
    i = i + 1  
    
for i in range(0, 36):
    List = [Table1['Summer 2 Day Precip'][i], Table2['Summer 2 Day Precip'][i],  Table3['Summer 2 Day Precip'][i],
              Table4['Summer 2 Day Precip'][i], Table5['Summer 2 Day Precip'][i],  Table6['Summer 2 Day Precip'][i],
              Table7['Summer 2 Day Precip'][i], Table8['Summer 2 Day Precip'][i], Table9['Summer 2 Day Precip'][i],
              Table10['Summer 2 Day Precip'][i], Table11['Summer 2 Day Precip'][i], Table12['Summer 2 Day Precip'][i],
              Table13['Summer 2 Day Precip'][i], Table14['Summer 2 Day Precip'][i], Table15['Summer 2 Day Precip'][i],
              Table16['Summer 2 Day Precip'][i], Table17['Summer 2 Day Precip'][i], Table18['Summer 2 Day Precip'][i],
              Table19['Summer 2 Day Precip'][i], Table20['Summer 2 Day Precip'][i], Table21['Summer 2 Day Precip'][i],
              Table22['Summer 2 Day Precip'][i], Table23['Summer 2 Day Precip'][i], Table24['Summer 2 Day Precip'][i],
              Table25['Summer 2 Day Precip'][i], Table26['Summer 2 Day Precip'][i], Table27['Summer 2 Day Precip'][i],
              Table28['Summer 2 Day Precip'][i], Table29['Summer 2 Day Precip'][i], Table30['Summer 2 Day Precip'][i],
              Table31['Summer 2 Day Precip'][i], Table32['Summer 2 Day Precip'][i], Table33['Summer 2 Day Precip'][i],
              Table34['Summer 2 Day Precip'][i], Table35['Summer 2 Day Precip'][i], Table36['Summer 2 Day Precip'][i],
              Table37['Summer 2 Day Precip'][i], Table38['Summer 2 Day Precip'][i], Table39['Summer 2 Day Precip'][i],
              Table40['Summer 2 Day Precip'][i], Table41['Summer 2 Day Precip'][i], Table42['Summer 2 Day Precip'][i],
              Table43['Summer 2 Day Precip'][i], Table44['Summer 2 Day Precip'][i], Table45['Summer 2 Day Precip'][i],
              Table46['Summer 2 Day Precip'][i], Table47['Summer 2 Day Precip'][i], Table48['Summer 2 Day Precip'][i],
              Table49['Summer 2 Day Precip'][i], Table50['Summer 2 Day Precip'][i], Table51['Summer 2 Day Precip'][i],
              Table52['Summer 2 Day Precip'][i]]
    Summer2DayMax.insert(i, max(List))
    Summer2DayStation.insert(i, (List.index(max(List))+1)) #lists the number of the station with the max based on above
    i = i + 1
    
for i in range(0, 36):
    List = [Table1['Fall 2 Day Precip'][i], Table2['Fall 2 Day Precip'][i],  Table3['Fall 2 Day Precip'][i],
              Table4['Fall 2 Day Precip'][i], Table5['Fall 2 Day Precip'][i],  Table6['Fall 2 Day Precip'][i],
              Table7['Fall 2 Day Precip'][i], Table8['Fall 2 Day Precip'][i], Table9['Fall 2 Day Precip'][i],
              Table10['Fall 2 Day Precip'][i], Table11['Fall 2 Day Precip'][i], Table12['Fall 2 Day Precip'][i],
              Table13['Fall 2 Day Precip'][i], Table14['Fall 2 Day Precip'][i], Table15['Fall 2 Day Precip'][i],
              Table16['Fall 2 Day Precip'][i], Table17['Fall 2 Day Precip'][i], Table18['Fall 2 Day Precip'][i],
              Table19['Fall 2 Day Precip'][i], Table20['Fall 2 Day Precip'][i], Table21['Fall 2 Day Precip'][i],
              Table22['Fall 2 Day Precip'][i], Table23['Fall 2 Day Precip'][i], Table24['Fall 2 Day Precip'][i],
              Table25['Fall 2 Day Precip'][i], Table26['Fall 2 Day Precip'][i], Table27['Fall 2 Day Precip'][i],
              Table28['Fall 2 Day Precip'][i], Table29['Fall 2 Day Precip'][i], Table30['Fall 2 Day Precip'][i],
              Table31['Fall 2 Day Precip'][i], Table32['Fall 2 Day Precip'][i], Table33['Fall 2 Day Precip'][i],
              Table34['Fall 2 Day Precip'][i], Table35['Fall 2 Day Precip'][i], Table36['Fall 2 Day Precip'][i],
              Table37['Fall 2 Day Precip'][i], Table38['Fall 2 Day Precip'][i], Table39['Fall 2 Day Precip'][i],
              Table40['Fall 2 Day Precip'][i], Table41['Fall 2 Day Precip'][i], Table42['Fall 2 Day Precip'][i],
              Table43['Fall 2 Day Precip'][i], Table44['Fall 2 Day Precip'][i], Table45['Fall 2 Day Precip'][i],
              Table46['Fall 2 Day Precip'][i], Table47['Fall 2 Day Precip'][i], Table48['Fall 2 Day Precip'][i],
              Table49['Fall 2 Day Precip'][i], Table50['Fall 2 Day Precip'][i], Table51['Fall 2 Day Precip'][i],
              Table52['Fall 2 Day Precip'][i]]
    Fall2DayMax.insert(i, max(List))
    Fall2DayStation.insert(i, (List.index(max(List))+1)) #lists the number of the station with the max based on above
    i = i + 1
    

df1 = pd.DataFrame({'Winter 1 Day Max': Winter1DayMax})
df2 = pd.DataFrame({'Spring 1 Day Max': Spring1DayMax})
df3 = pd.DataFrame({'Summer 1 Day Max': Summer1DayMax})
df4 = pd.DataFrame({'Fall 1 Day Max': Fall1DayMax})
df5 = pd.DataFrame({'Winter 2 Day Max': Winter2DayMax})
df6 = pd.DataFrame({'Spring 2 Day Max': Spring2DayMax})
df7 = pd.DataFrame({'Summer 2 Day Max': Summer2DayMax})
df8 = pd.DataFrame({'Fall 2 Day Max': Fall2DayMax})


dftot = pd.concat([df1, df2, df4, df5, df7, df8], axis=1)
dftot.to_csv('Maximum Rainfalls.csv')
